# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# ## Importing and Reading Data as DataFrame

# %%
df = pd.read_csv("../data/train_.csv")
df.shape
# Out:
# (1460, 68)

# %% [markdown]
# ## Getting Info about data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 68 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotFrontage    1201 non-null   float64
#  1   LotArea        1460 non-null   int64
#  2   MasVnrArea     1452 non-null   float64
#  3   BsmtFinSF1     1460 non-null   int64
#  4   BsmtFinSF2     1460 non-null   int64
#  5   BsmtUnfSF      1460 non-null   int64
#  6   2ndFlrSF       1460 non-null   int64
#  7   LowQualFinSF   1460 non-null   int64
#  8   WoodDeckSF     1460 non-null   int64
#  9   OpenPorchSF    1460 non-null   int64
#  10  EnclosedPorch  1460 non-null   int64
#  11  3SsnPorch      1460 non-null   int64
#  12  ScreenPorch    1460 non-null   int64
#  13  PoolArea       1460 non-null   int64
#  14  MiscVal        1460 non-null   int64
#  15  YrSold         1460 non-null   int64
#  16  SalePrice      1460 non-null   int64
#  17  MSZoning       1460 non-null   object
#  18  Street         1460 non-null   object
#  19  LotShape       1460 non-null   object
#  20  LandContour    1460 non-null   object
#  21  Utilities      1460 non-null   object
#  22  LotConfig      1460 non-null   object
#  23  LandSlope      1460 non-null   object
#  24  Neighborhood   1460 non-null   object
#  25  Condition1     1460 non-null   object
#  26  Condition2     1460 non-null   object
#  27  BldgType       1460 non-null   object
#  28  HouseStyle     1460 non-null   object
#  29  RoofStyle      1460 non-null   object
#  30  RoofMatl       1460 non-null   object
#  31  Exterior1st    1460 non-null   object
#  32  Exterior2nd    1460 non-null   object
#  33  MasVnrType     1452 non-null   object
#  34  ExterQual      1460 non-null   object
#  35  ExterCond      1460 non-null   object
#  36  Foundation     1460 non-null   object
#  37  BsmtQual       1423 non-null   object
#  38  BsmtCond       1423 non-null   object
#  39  BsmtExposure   1422 non-null   object
#  40  BsmtFinType1   1423 non-null   object
#  41  BsmtFinType2   1422 non-null   object
#  42  Heating        1460 non-null   object
#  43  HeatingQC      1460 non-null   object
#  44  CentralAir     1460 non-null   object
#  45  Electrical     1459 non-null   object
#  46  KitchenQual    1460 non-null   object
#  47  Functional     1460 non-null   object
#  48  GarageType     1379 non-null   object
#  49  GarageFinish   1379 non-null   object
#  50  GarageQual     1379 non-null   object
#  51  GarageCond     1379 non-null   object
#  52  PavedDrive     1460 non-null   object
#  53  SaleType       1460 non-null   object
#  54  SaleCondition  1460 non-null   object
#  55  MSSubClass     1460 non-null   int64
#  56  OverallQual    1460 non-null   int64
#  57  OverallCond    1460 non-null   int64
#  58  BsmtFullBath   1460 non-null   int64
#  59  BsmtHalfBath   1460 non-null   int64
#  60  FullBath       1460 non-null   int64
#  61  HalfBath       1460 non-null   int64
#  62  BedroomAbvGr   1460 non-null   int64
#  63  KitchenAbvGr   1460 non-null   int64
#  64  TotRmsAbvGrd   1460 non-null   int64
#  65  Fireplaces     1460 non-null   int64
#  66  GarageCars     1460 non-null   int64
#  67  MoSold         1460 non-null   int64
# dtypes: float64(2), int64(28), object(38)
# memory usage: 775.8+ KB

# %% [markdown]
# ## Splitting data into Numerical and Categorical datapoints

# %%
numerical_data = df[['LotFrontage', 'LotArea', 
       'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
       'BsmtUnfSF', '2ndFlrSF', 'LowQualFinSF',
       'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
       'YrSold']]

target = df['SalePrice']

# %%
categorical_data = df[['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 
       'SaleType', 'SaleCondition', "MSSubClass", "OverallQual", "OverallCond", 
        "BsmtFullBath", "BsmtHalfBath", "FullBath", "HalfBath", "BedroomAbvGr", 
        "KitchenAbvGr", "TotRmsAbvGrd", "Fireplaces", "GarageCars", "MoSold"]]

# %% [markdown]
# ## Calculating Missing Data

# %%
def missingDataCalculator(df):
    missing_data_columns = []
    print('Total Length of DataFrame : ', len(df))
    print('*******************************************')
    
    for cols in df.columns:
        missing_data_points = df[cols].isnull().sum()
        data_percentage = (missing_data_points/len(df))*100
    
        if (data_percentage) > 0:
            print('Missing Data Column : ', cols)
            print('Missing Data Points : ', missing_data_points)
            print('Missing Data Percentage : ', data_percentage)
            print('*******************************************')
            missing_data_columns.append(cols)
        else:
            pass
        
    return missing_data_columns

# %% [markdown]
# ## Numerical Data

# %% [markdown]
# ### Basic Data Analysis

# %%
print('Shape_Numerical_Columns : ', numerical_data.shape)
print('****************************************************')
print('Describe_Numerical_Columns : ', numerical_data.describe())
print('****************************************************')
print('Info_Numerical_Columns : ', numerical_data.info())
# Out:
# Shape_Numerical_Columns :  (1460, 16)
# ****************************************************
# Describe_Numerical_Columns :         LotFrontage        LotArea   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1201.000000    1460.000000  1452.000000  1460.000000  1460.000000
# mean     70.049958   10516.828082   103.685262   443.639726    46.549315
# std      24.284752    9981.264932   181.066207   456.098091   161.319273
# min      21.000000    1300.000000     0.000000     0.000000     0.000000
# 25%      59.000000    7553.500000     0.000000     0.000000     0.000000
# 50%      69.000000    9478.500000     0.000000   383.500000     0.000000
# 75%      80.000000   11601.500000   166.000000   712.250000     0.000000
# max     313.000000  215245.000000  1600.000000  5644.000000  1474.000000
#
#          BsmtUnfSF     2ndFlrSF  LowQualFinSF   WoodDeckSF  OpenPorchSF  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean    567.240411   346.992466      5.844521    94.244521    46.660274
# std     441.866955   436.528436     48.623081   125.338794    66.256028
# min       0.000000     0.000000      0.000000     0.000000     0.000000
# 25%     223.000000     0.000000      0.000000     0.000000     0.000000
# 50%     477.500000     0.000000      0.000000     0.000000    25.000000
# 75%     808.000000   728.000000      0.000000   168.000000    68.000000
# max    2336.000000  2065.000000    572.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
#             YrSold
# count  1460.000000
# mean   2007.815753
# std       1.328095
# min    2006.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2010.000000
# ****************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotFrontage    1201 non-null   float64
#  1   LotArea        1460 non-null   int64
#  2   MasVnrArea     1452 non-null   float64
#  3   BsmtFinSF1     1460 non-null   int64
#  4   BsmtFinSF2     1460 non-null   int64
#  5   BsmtUnfSF      1460 non-null   int64
#  6   2ndFlrSF       1460 non-null   int64
#  7   LowQualFinSF   1460 non-null   int64
#  8   WoodDeckSF     1460 non-null   int64
#  9   OpenPorchSF    1460 non-null   int64
#  10  EnclosedPorch  1460 non-null   int64
#  11  3SsnPorch      1460 non-null   int64
#  12  ScreenPorch    1460 non-null   int64
#  13  PoolArea       1460 non-null   int64
#  14  MiscVal        1460 non-null   int64
#  15  YrSold         1460 non-null   int64
# dtypes: float64(2), int64(14)
# memory usage: 182.6 KB
# Info_Numerical_Columns :  None

# %% [markdown]
# #### There are some missing values in the data

# %% [markdown]
# ### Calculating % of Missing data

# %%
missingDataCalculator(numerical_data)
# Out:
# Total Length of DataFrame :  1460
# *******************************************
# Missing Data Column :  LotFrontage
# Missing Data Points :  259
# Missing Data Percentage :  17.73972602739726
# *******************************************
# Missing Data Column :  MasVnrArea
# Missing Data Points :  8
# Missing Data Percentage :  0.547945205479452
# *******************************************
# ['LotFrontage', 'MasVnrArea']

# %% [markdown]
# ### Imputing Missing Data

# %%
numerical_missing_values_columns = ['LotFrontage', 'MasVnrArea']

for missing_col in numerical_missing_values_columns:
    numerical_data[missing_col] = numerical_data[missing_col].fillna(numerical_data[missing_col].mean())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\1938148949.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_data[missing_col] = numerical_data[missing_col].fillna(numerical_data[missing_col].mean())

# %% [markdown]
# ### Calculating % of Missing data

# %%
missingDataCalculator(numerical_data)
# Out:
# Total Length of DataFrame :  1460
# *******************************************
# []

# %% [markdown]
# ### Encoding Data

# %% [markdown]
# ### Numerical Data

# %%
numerical_data
# Out:
#       LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0            65.0     8450       196.0         706           0        150
# 1            80.0     9600         0.0         978           0        284
# 2            68.0    11250       162.0         486           0        434
# 3            60.0     9550         0.0         216           0        540
# 4            84.0    14260       350.0         655           0        490
# ...           ...      ...         ...         ...         ...        ...
# 1455         62.0     7917         0.0           0           0        953
# 1456         85.0    13175       119.0         790         163        589
# 1457         66.0     9042         0.0         275           0        877
# 1458         68.0     9717         0.0          49        1029          0
# 1459         75.0     9937         0.0         830         290        136
#
#       2ndFlrSF  LowQualFinSF  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 0          854             0           0           61              0
# 1            0             0         298            0              0
# 2          866             0           0           42              0
# 3          756             0           0           35            272
# 4         1053             0         192           84              0
# ...        ...           ...         ...          ...            ...
# 1455       694             0           0           40              0
# 1456         0             0         349            0              0
# 1457      1152             0           0           60              0
# 1458         0             0         366            0            112
# 1459         0             0         736           68              0
#
#       3SsnPorch  ScreenPorch  PoolArea  MiscVal  YrSold
# 0             0            0         0        0    2008
# 1             0            0         0        0    2007
# 2             0            0         0        0    2008
# 3             0            0         0        0    2006
# 4             0            0         0        0    2008
# ...         ...          ...       ...      ...     ...
# 1455          0            0         0        0    2007
# 1456          0            0         0        0    2010
# 1457          0            0         0     2500    2010
# 1458          0            0         0        0    2010
# 1459          0            0         0        0    2008
#
# [1460 rows x 16 columns]

# %%
scaler = StandardScaler()
numerical_data = scaler.fit_transform(numerical_data)

# %%
numerical_data
# Out:
# array([[-0.22937175, -0.20714171,  0.51141841, ..., -0.06869175,
#         -0.08768781,  0.13877749],
#        [ 0.4519361 , -0.09188637, -0.57441047, ..., -0.06869175,
#         -0.08768781, -0.61443862],
#        [-0.09311018,  0.07347998,  0.32306034, ..., -0.06869175,
#         -0.08768781,  0.13877749],
#        ...,
#        [-0.18395123, -0.14781027, -0.57441047, ..., -0.06869175,
#          4.95311151,  1.64520971],
#        [-0.09311018, -0.08016039, -0.57441047, ..., -0.06869175,
#         -0.08768781,  1.64520971],
#        [ 0.22483348, -0.05811155, -0.57441047, ..., -0.06869175,
#         -0.08768781,  0.13877749]])

# %%
numerical_data_scaled = pd.DataFrame(numerical_data, columns=['LotFrontage', 'LotArea', 
                                                               'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
                                                               'BsmtUnfSF', '2ndFlrSF', 'LowQualFinSF',
                                                               'WoodDeckSF', 'OpenPorchSF',
                                                               'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 
                                                               'PoolArea', 'MiscVal',
                                                               'YrSold'])

# %%
numerical_data_scaled
# Out:
#       LotFrontage   LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0       -0.229372 -0.207142    0.511418    0.575425   -0.288653  -0.944591
# 1        0.451936 -0.091886   -0.574410    1.171992   -0.288653  -0.641228
# 2       -0.093110  0.073480    0.323060    0.092907   -0.288653  -0.301643
# 3       -0.456474 -0.096897   -0.574410   -0.499274   -0.288653  -0.061670
# 4        0.633618  0.375148    1.364570    0.463568   -0.288653  -0.174865
# ...           ...       ...         ...         ...         ...        ...
# 1455    -0.365633 -0.260560   -0.574410   -0.973018   -0.288653   0.873321
# 1456     0.679039  0.266407    0.084843    0.759659    0.722112   0.049262
# 1457    -0.183951 -0.147810   -0.574410   -0.369871   -0.288653   0.701265
# 1458    -0.093110 -0.080160   -0.574410   -0.865548    6.092188  -1.284176
# 1459     0.224833 -0.058112   -0.574410    0.847389    1.509640  -0.976285
#
#       2ndFlrSF  LowQualFinSF  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 0     1.161852     -0.120242   -0.752176     0.216503      -0.359325
# 1    -0.795163     -0.120242    1.626195    -0.704483      -0.359325
# 2     1.189351     -0.120242   -0.752176    -0.070361      -0.359325
# 3     0.937276     -0.120242   -0.752176    -0.176048       4.092524
# 4     1.617877     -0.120242    0.780197     0.563760      -0.359325
# ...        ...           ...         ...          ...            ...
# 1455  0.795198     -0.120242   -0.752176    -0.100558      -0.359325
# 1456 -0.795163     -0.120242    2.033231    -0.704483      -0.359325
# 1457  1.844744     -0.120242   -0.752176     0.201405      -0.359325
# 1458 -0.795163     -0.120242    2.168910    -0.704483       1.473789
# 1459 -0.795163     -0.120242    5.121921     0.322190      -0.359325
#
#       3SsnPorch  ScreenPorch  PoolArea   MiscVal    YrSold
# 0     -0.116339    -0.270208 -0.068692 -0.087688  0.138777
# 1     -0.116339    -0.270208 -0.068692 -0.087688 -0.614439
# 2     -0.116339    -0.270208 -0.068692 -0.087688  0.138777
# 3     -0.116339    -0.270208 -0.068692 -0.087688 -1.367655
# 4     -0.116339    -0.270208 -0.068692 -0.087688  0.138777
# ...         ...          ...       ...       ...       ...
# 1455  -0.116339    -0.270208 -0.068692 -0.087688 -0.614439
# 1456  -0.116339    -0.270208 -0.068692 -0.087688  1.645210
# 1457  -0.116339    -0.270208 -0.068692  4.953112  1.645210
# 1458  -0.116339    -0.270208 -0.068692 -0.087688  1.645210
# 1459  -0.116339    -0.270208 -0.068692 -0.087688  0.138777
#
# [1460 rows x 16 columns]

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# ### Basic Data Analysis

# %%
print('Shape_Categorical_Columns : ', categorical_data.shape)
print('****************************************************')
print('Describe_Categorical_Columns : ', categorical_data.describe())
print('****************************************************')
print('Info_Categorical_Columns : ', categorical_data.info())
# Out:
# Shape_Categorical_Columns :  (1460, 51)
# ****************************************************
# Describe_Categorical_Columns :          MSSubClass  OverallQual  OverallCond  BsmtFullBath  BsmtHalfBath  \
# count  1460.000000  1460.000000  1460.000000   1460.000000   1460.000000
# mean     56.897260     6.099315     5.575342      0.425342      0.057534
# std      42.300571     1.382997     1.112799      0.518911      0.238753
# min      20.000000     1.000000     1.000000      0.000000      0.000000
# 25%      20.000000     5.000000     5.000000      0.000000      0.000000
# 50%      50.000000     6.000000     5.000000      0.000000      0.000000
# 75%      70.000000     7.000000     6.000000      1.000000      0.000000
# max     190.000000    10.000000     9.000000      3.000000      2.000000
#
#           FullBath     HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# count  1460.000000  1460.000000   1460.000000   1460.000000   1460.000000
# mean      1.565068     0.382877      2.866438      1.046575      6.517808
# std       0.550916     0.502885      0.815778      0.220338      1.625393
# min       0.000000     0.000000      0.000000      0.000000      2.000000
# 25%       1.000000     0.000000      2.000000      1.000000      5.000000
# 50%       2.000000     0.000000      3.000000      1.000000      6.000000
# 75%       2.000000     1.000000      3.000000      1.000000      7.000000
# max       3.000000     2.000000      8.000000      3.000000     14.000000
#
#         Fireplaces   GarageCars       MoSold
# count  1460.000000  1460.000000  1460.000000
# mean      0.613014     1.767123     6.321918
# std       0.644666     0.747315     2.703626
# min       0.000000     0.000000     1.000000
# 25%       0.000000     1.000000     5.000000
# 50%       1.000000     2.000000     6.000000
# 75%       1.000000     2.000000     8.000000
# max       3.000000     4.000000    12.000000
# ****************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 51 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   object
#  1   Street         1460 non-null   object
#  2   LotShape       1460 non-null   object
#  3   LandContour    1460 non-null   object
#  4   Utilities      1460 non-null   object
#  5   LotConfig      1460 non-null   object
#  6   LandSlope      1460 non-null   object
#  7   Neighborhood   1460 non-null   object
#  8   Condition1     1460 non-null   object
#  9   Condition2     1460 non-null   object
#  10  BldgType       1460 non-null   object
#  11  HouseStyle     1460 non-null   object
#  12  RoofStyle      1460 non-null   object
#  13  RoofMatl       1460 non-null   object
#  14  Exterior1st    1460 non-null   object
#  15  Exterior2nd    1460 non-null   object
#  16  MasVnrType     1452 non-null   object
#  17  ExterQual      1460 non-null   object
#  18  ExterCond      1460 non-null   object
#  19  Foundation     1460 non-null   object
#  20  BsmtQual       1423 non-null   object
#  21  BsmtCond       1423 non-null   object
#  22  BsmtExposure   1422 non-null   object
#  23  BsmtFinType1   1423 non-null   object
#  24  BsmtFinType2   1422 non-null   object
#  25  Heating        1460 non-null   object
#  26  HeatingQC      1460 non-null   object
#  27  CentralAir     1460 non-null   object
#  28  Electrical     1459 non-null   object
#  29  KitchenQual    1460 non-null   object
#  30  Functional     1460 non-null   object
#  31  GarageType     1379 non-null   object
#  32  GarageFinish   1379 non-null   object
#  33  GarageQual     1379 non-null   object
#  34  GarageCond     1379 non-null   object
#  35  PavedDrive     1460 non-null   object
#  36  SaleType       1460 non-null   object
#  37  SaleCondition  1460 non-null   object
#  38  MSSubClass     1460 non-null   int64
#  39  OverallQual    1460 non-null   int64
#  40  OverallCond    1460 non-null   int64
#  41  BsmtFullBath   1460 non-null   int64
#  42  BsmtHalfBath   1460 non-null   int64
#  43  FullBath       1460 non-null   int64
#  44  HalfBath       1460 non-null   int64
#  45  BedroomAbvGr   1460 non-null   int64
#  46  KitchenAbvGr   1460 non-null   int64
#  47  TotRmsAbvGrd   1460 non-null   int64
#  48  Fireplaces     1460 non-null   int64
#  49  GarageCars     1460 non-null   int64
#  50  MoSold         1460 non-null   int64
# dtypes: int64(13), object(38)
# memory usage: 581.8+ KB
# Info_Categorical_Columns :  None

# %% [markdown]
# ### Calculating % of Missing data

# %%
missing_data_columns = missingDataCalculator(categorical_data)
# Out:
# Total Length of DataFrame :  1460
# *******************************************
# Missing Data Column :  MasVnrType
# Missing Data Points :  8
# Missing Data Percentage :  0.547945205479452
# *******************************************
# Missing Data Column :  BsmtQual
# Missing Data Points :  37
# Missing Data Percentage :  2.5342465753424657
# *******************************************
# Missing Data Column :  BsmtCond
# Missing Data Points :  37
# Missing Data Percentage :  2.5342465753424657
# *******************************************
# Missing Data Column :  BsmtExposure
# Missing Data Points :  38
# Missing Data Percentage :  2.6027397260273974
# *******************************************
# Missing Data Column :  BsmtFinType1
# Missing Data Points :  37
# Missing Data Percentage :  2.5342465753424657
# *******************************************
# Missing Data Column :  BsmtFinType2
# Missing Data Points :  38
# Missing Data Percentage :  2.6027397260273974
# *******************************************
# Missing Data Column :  Electrical
# Missing Data Points :  1
# Missing Data Percentage :  0.0684931506849315
# *******************************************
# Missing Data Column :  GarageType
# Missing Data Points :  81
# Missing Data Percentage :  5.5479452054794525
# *******************************************
# Missing Data Column :  GarageFinish
# Missing Data Points :  81
# Missing Data Percentage :  5.5479452054794525
# *******************************************
# Missing Data Column :  GarageQual
# Missing Data Points :  81
# Missing Data Percentage :  5.5479452054794525
# *******************************************
# Missing Data Column :  GarageCond
# Missing Data Points :  81
# Missing Data Percentage :  5.5479452054794525
# *******************************************

# %% [markdown]
# ### Imputing Categorical Missing Data

# %%
for missing_col in missing_data_columns:
    categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\2059958622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\2059958622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\2059958622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\2059958622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\2059958622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\2059958622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\2059958622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\2059958622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\2059958622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\2059958622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4264\2059958622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_data[missing_col] = categorical_data[missing_col].fillna(str(categorical_data[missing_col].mode()))

# %% [markdown]
# ### Calculating % of Missing data

# %%
missingDataCalculator(categorical_data)
# Out:
# Total Length of DataFrame :  1460
# *******************************************
# []

# %% [markdown]
# ### Concatenating Numerical and Categorical Data

# %%
dfs = [numerical_data_scaled, categorical_data]
data = pd.concat(dfs, axis=1)

# %%
data.shape
# Out:
# (1460, 67)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 67 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotFrontage    1460 non-null   float64
#  1   LotArea        1460 non-null   float64
#  2   MasVnrArea     1460 non-null   float64
#  3   BsmtFinSF1     1460 non-null   float64
#  4   BsmtFinSF2     1460 non-null   float64
#  5   BsmtUnfSF      1460 non-null   float64
#  6   2ndFlrSF       1460 non-null   float64
#  7   LowQualFinSF   1460 non-null   float64
#  8   WoodDeckSF     1460 non-null   float64
#  9   OpenPorchSF    1460 non-null   float64
#  10  EnclosedPorch  1460 non-null   float64
#  11  3SsnPorch      1460 non-null   float64
#  12  ScreenPorch    1460 non-null   float64
#  13  PoolArea       1460 non-null   float64
#  14  MiscVal        1460 non-null   float64
#  15  YrSold         1460 non-null   float64
#  16  MSZoning       1460 non-null   object
#  17  Street         1460 non-null   object
#  18  LotShape       1460 non-null   object
#  19  LandContour    1460 non-null   object
#  20  Utilities      1460 non-null   object
#  21  LotConfig      1460 non-null   object
#  22  LandSlope      1460 non-null   object
#  23  Neighborhood   1460 non-null   object
#  24  Condition1     1460 non-null   object
#  25  Condition2     1460 non-null   object
#  26  BldgType       1460 non-null   object
#  27  HouseStyle     1460 non-null   object
#  28  RoofStyle      1460 non-null   object
#  29  RoofMatl       1460 non-null   object
#  30  Exterior1st    1460 non-null   object
#  31  Exterior2nd    1460 non-null   object
#  32  MasVnrType     1460 non-null   object
#  33  ExterQual      1460 non-null   object
#  34  ExterCond      1460 non-null   object
#  35  Foundation     1460 non-null   object
#  36  BsmtQual       1460 non-null   object
#  37  BsmtCond       1460 non-null   object
#  38  BsmtExposure   1460 non-null   object
#  39  BsmtFinType1   1460 non-null   object
#  40  BsmtFinType2   1460 non-null   object
#  41  Heating        1460 non-null   object
#  42  HeatingQC      1460 non-null   object
#  43  CentralAir     1460 non-null   object
#  44  Electrical     1460 non-null   object
#  45  KitchenQual    1460 non-null   object
#  46  Functional     1460 non-null   object
#  47  GarageType     1460 non-null   object
#  48  GarageFinish   1460 non-null   object
#  49  GarageQual     1460 non-null   object
#  50  GarageCond     1460 non-null   object
#  51  PavedDrive     1460 non-null   object
#  52  SaleType       1460 non-null   object
#  53  SaleCondition  1460 non-null   object
#  54  MSSubClass     1460 non-null   int64
#  55  OverallQual    1460 non-null   int64
#  56  OverallCond    1460 non-null   int64
#  57  BsmtFullBath   1460 non-null   int64
#  58  BsmtHalfBath   1460 non-null   int64
#  59  FullBath       1460 non-null   int64
#  60  HalfBath       1460 non-null   int64
#  61  BedroomAbvGr   1460 non-null   int64
#  62  KitchenAbvGr   1460 non-null   int64
#  63  TotRmsAbvGrd   1460 non-null   int64
#  64  Fireplaces     1460 non-null   int64
#  65  GarageCars     1460 non-null   int64
#  66  MoSold         1460 non-null   int64
# dtypes: float64(16), int64(13), object(38)
# memory usage: 764.3+ KB

# %% [markdown]
# ### Encoding

# %% [markdown]
# ### Categorical Data

# %%
categorical_data
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... BsmtFullBath BsmtHalfBath  \
# 0         CollgCr       Norm       Norm  ...            1            0
# 1         Veenker      Feedr       Norm  ...            0            1
# 2         CollgCr       Norm       Norm  ...            1            0
# 3         Crawfor       Norm       Norm  ...            1            0
# 4         NoRidge       Norm       Norm  ...            1            0
# ...           ...        ...        ...  ...          ...          ...
# 1455      Gilbert       Norm       Norm  ...            0            0
# 1456       NWAmes       Norm       Norm  ...            1            0
# 1457      Crawfor       Norm       Norm  ...            0            0
# 1458        NAmes       Norm       Norm  ...            1            0
# 1459      Edwards       Norm       Norm  ...            1            0
#
#      FullBath HalfBath BedroomAbvGr KitchenAbvGr TotRmsAbvGrd Fireplaces  \
# 0           2        1            3            1            8          0
# 1           2        0            3            1            6          1
# 2           2        1            3            1            6          1
# 3           1        0            3            1            7          1
# 4           2        1            4            1            9          1
# ...       ...      ...          ...          ...          ...        ...
# 1455        2        1            3            1            7          1
# 1456        2        0            3            1            7          2
# 1457        2        0            4            1            9          2
# 1458        1        0            2            1            5          0
# 1459        1        1            3            1            6          0
#
#      GarageCars MoSold
# 0             2      2
# 1             2      5
# 2             2      9
# 3             3      2
# 4             3     12
# ...         ...    ...
# 1455          2      8
# 1456          2      2
# 1457          1      5
# 1458          1      4
# 1459          1      6
#
# [1460 rows x 51 columns]

# %%
# categorical_data = df.select_dtypes(['O'])

# %%
categorical_data
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... BsmtFullBath BsmtHalfBath  \
# 0         CollgCr       Norm       Norm  ...            1            0
# 1         Veenker      Feedr       Norm  ...            0            1
# 2         CollgCr       Norm       Norm  ...            1            0
# 3         Crawfor       Norm       Norm  ...            1            0
# 4         NoRidge       Norm       Norm  ...            1            0
# ...           ...        ...        ...  ...          ...          ...
# 1455      Gilbert       Norm       Norm  ...            0            0
# 1456       NWAmes       Norm       Norm  ...            1            0
# 1457      Crawfor       Norm       Norm  ...            0            0
# 1458        NAmes       Norm       Norm  ...            1            0
# 1459      Edwards       Norm       Norm  ...            1            0
#
#      FullBath HalfBath BedroomAbvGr KitchenAbvGr TotRmsAbvGrd Fireplaces  \
# 0           2        1            3            1            8          0
# 1           2        0            3            1            6          1
# 2           2        1            3            1            6          1
# 3           1        0            3            1            7          1
# 4           2        1            4            1            9          1
# ...       ...      ...          ...          ...          ...        ...
# 1455        2        1            3            1            7          1
# 1456        2        0            3            1            7          2
# 1457        2        0            4            1            9          2
# 1458        1        0            2            1            5          0
# 1459        1        1            3            1            6          0
#
#      GarageCars MoSold
# 0             2      2
# 1             2      5
# 2             2      9
# 3             3      2
# 4             3     12
# ...         ...    ...
# 1455          2      8
# 1456          2      2
# 1457          1      5
# 1458          1      4
# 1459          1      6
#
# [1460 rows x 51 columns]

# %%
categorical_data = categorical_data.apply(LabelEncoder().fit_transform)

# %%
categorical_data
# Out:
#       MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  \
# 0            3       1         3            3          0          4
# 1            3       1         3            3          0          2
# 2            3       1         0            3          0          4
# 3            3       1         0            3          0          0
# 4            3       1         0            3          0          2
# ...        ...     ...       ...          ...        ...        ...
# 1455         3       1         3            3          0          4
# 1456         3       1         3            3          0          4
# 1457         3       1         3            3          0          4
# 1458         3       1         3            3          0          4
# 1459         3       1         3            3          0          4
#
#       LandSlope  Neighborhood  Condition1  Condition2  ...  BsmtFullBath  \
# 0             0             5           2           2  ...             1
# 1             0            24           1           2  ...             0
# 2             0             5           2           2  ...             1
# 3             0             6           2           2  ...             1
# 4             0            15           2           2  ...             1
# ...         ...           ...         ...         ...  ...           ...
# 1455          0             8           2           2  ...             0
# 1456          0            14           2           2  ...             1
# 1457          0             6           2           2  ...             0
# 1458          0            12           2           2  ...             1
# 1459          0             7           2           2  ...             1
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0                0         2         1             3             1
# 1                1         2         0             3             1
# 2                0         2         1             3             1
# 3                0         1         0             3             1
# 4                0         2         1             4             1
# ...            ...       ...       ...           ...           ...
# 1455             0         2         1             3             1
# 1456             0         2         0             3             1
# 1457             0         2         0             4             1
# 1458             0         1         0             2             1
# 1459             0         1         1             3             1
#
#       TotRmsAbvGrd  Fireplaces  GarageCars  MoSold
# 0                6           0           2       1
# 1                4           1           2       4
# 2                4           1           2       8
# 3                5           1           3       1
# 4                7           1           3      11
# ...            ...         ...         ...     ...
# 1455             5           1           2       7
# 1456             5           2           2       1
# 1457             7           2           1       4
# 1458             3           0           1       3
# 1459             4           0           1       5
#
# [1460 rows x 51 columns]

# %% [markdown]
# ### Concatenating Numerical and Categorical Data

# %%
data = pd.concat([numerical_data_scaled, categorical_data], axis = 1)

# %% [markdown]
# ### Splitting Target and Train test Splits

# %%
data['SalePrice'] = target

# %%
target.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: SalePrice, Length: 1460, dtype: bool

# %%
target.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1460 entries, 0 to 1459
# Series name: SalePrice
# Non-Null Count  Dtype
# --------------  -----
# 1460 non-null   int64
# dtypes: int64(1)
# memory usage: 11.5 KB

# %%
target.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# #### Adding target to DataFrame

# %% [markdown]
# ### Saving to a DataFrame

# %%
data.to_csv('../data/train__.csv', index = False)
